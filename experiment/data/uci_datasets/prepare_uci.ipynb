# %% [markdown]
# ## collect splits

# %%
# !git clone https://github.com/yaringal/DropoutUncertaintyExps.git
# Out:
# Cloning into 'DropoutUncertaintyExps'...
# remote: Enumerating objects: 1222, done.
# remote: Total 1222 (delta 0), reused 0 (delta 0), pack-reused 1222 (from 1)
# Receiving objects: 100% (1222/1222), 5.03 MiB | 12.85 MiB/s, done.
# Resolving deltas: 100% (382/382), done.
# Updating files: 100% (487/487), done.

# %%
# using code from https://github.com/yaringal/DropoutUncertaintyExps.git


import numpy as np
import pandas as pd

class SplitLoader:
    "load each split from the the given UCI dataset name"

    def __init__(self, data_directory):
        _DATA_DIRECTORY_PATH = "./DropoutUncertaintyExps/UCI_Datasets/" + data_directory + "/data/"
        self._DATA_DIRECTORY_PATH = _DATA_DIRECTORY_PATH
        _DATA_FILE = _DATA_DIRECTORY_PATH + "data.txt"
        _INDEX_FEATURES_FILE = _DATA_DIRECTORY_PATH + "index_features.txt"
        _INDEX_TARGET_FILE = _DATA_DIRECTORY_PATH + "index_target.txt"
        _N_SPLITS_FILE = _DATA_DIRECTORY_PATH + "n_splits.txt"

        data = np.loadtxt(_DATA_FILE)
        index_features = np.loadtxt(_INDEX_FEATURES_FILE)
        index_target = np.loadtxt(_INDEX_TARGET_FILE)

        self.X = data[ : , [int(i) for i in index_features.tolist()] ]
        self.y = data[ : , int(index_target.tolist()) ]

        self.n_splits = np.loadtxt(_N_SPLITS_FILE)
        # print name of the dataset and nsplits
        print ('Dataset: ' + data_directory)
        print ('Number of splits: ' + str(self.n_splits))

        
    def __iter__(self):
        yield from self.splits_generator()

    def splits_generator(self):
        for split_num in range(int(self.n_splits)):
            # We load the indexes of the training and test sets
            index_train_path = self._DATA_DIRECTORY_PATH + "index_train_" + str(split_num) + ".txt"
            index_test_path = self._DATA_DIRECTORY_PATH + "index_test_" + str(split_num) + ".txt"
            print ('Loading file: ' + index_train_path)
            print ('Loading file: ' + index_test_path)
            index_train = np.loadtxt(index_train_path)
            index_test = np.loadtxt(index_test_path)

            X_train = self.X[ [int(i) for i in index_train.tolist()] ]
            y_train = self.y[ [int(i) for i in index_train.tolist()] ]
            
            X_test = self.X[ [int(i) for i in index_test.tolist()] ]
            y_test = self.y[ [int(i) for i in index_test.tolist()] ]

            X_train_original = X_train
            y_train_original = y_train
            num_training_examples = int(0.8 * X_train.shape[0])
            X_validation = X_train[num_training_examples:, :]
            y_validation = y_train[num_training_examples:]
            X_train = X_train[0:num_training_examples, :]
            y_train = y_train[0:num_training_examples]
            
            # Printing the size of the training, validation and test sets
            print ('Number of training examples: ' + str(X_train.shape[0]))
            print ('Number of validation examples: ' + str(X_validation.shape[0]))
            print ('Number of test examples: ' + str(X_test.shape[0]))
            print ('Number of train_original examples: ' + str(X_train_original.shape[0]))
            yield (X_train, y_train, X_validation, y_validation, 
                X_test, y_test, X_train_original, y_train_original)

# %%
# !pwd
# Out:
# /mnt/idms/home/jungadam/spring/experiment/data/uci_datasets

# %%
UCI_NAMES = ["bostonHousing", "concrete", "energy", "kin8nm", 
             "naval-propulsion-plant", "power-plant", "protein-tertiary-structure", 
             "wine-quality-red", "yacht"]

# UCI_NAMES = ["bostonHousing"]

from subprocess import call
import pandas as pd

EXPORTED_SPILTS_PATH = "exported_splits"
call(["mkdir", "-p", EXPORTED_SPILTS_PATH])

for ds_name in UCI_NAMES:
    print("________________________________\n\n")
    DS_PATH = EXPORTED_SPILTS_PATH + "/" + ds_name
    call(["mkdir", "-p", DS_PATH])

    ldr = SplitLoader(ds_name)
    for idx, split in enumerate(ldr):
        SPLIT_PATH = DS_PATH + "/split_" + str(idx)
        call(["mkdir", "-p", SPLIT_PATH])

        X_train, y_train, X_validation, y_validation, \
            X_test, y_test, X_train_original, y_train_original = split
        
        # save to csv
        pd.DataFrame(X_train).to_csv(SPLIT_PATH + "/X_train.csv", index=False)
        pd.DataFrame(y_train).to_csv(SPLIT_PATH + "/y_train.csv", index=False)
        pd.DataFrame(X_validation).to_csv(SPLIT_PATH + "/X_validation.csv", index=False)
        pd.DataFrame(y_validation).to_csv(SPLIT_PATH + "/y_validation.csv", index=False)
        pd.DataFrame(X_test).to_csv(SPLIT_PATH + "/X_test.csv", index=False)
        pd.DataFrame(y_test).to_csv(SPLIT_PATH + "/y_test.csv", index=False)
# Out:
# ________________________________
#
#
# Dataset: bostonHousing
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_0.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_1.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_2.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_3.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_4.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_5.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_6.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_7.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_8.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_9.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_10.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_11.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_12.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_13.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_14.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_15.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_16.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_17.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_18.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/bostonHousing/data/index_test_19.txt
# Number of training examples: 364
# Number of validation examples: 91
# Number of test examples: 51
# Number of train_original examples: 455
# ________________________________
#
#
# Dataset: concrete
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_0.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_1.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_2.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_3.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_4.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_5.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_6.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_7.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_8.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_9.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_10.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_11.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_12.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_13.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_14.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_15.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_16.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_17.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_18.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/concrete/data/index_test_19.txt
# Number of training examples: 741
# Number of validation examples: 186
# Number of test examples: 103
# Number of train_original examples: 927
# ________________________________
#
#
# Dataset: energy
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_0.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_1.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_2.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_3.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_4.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_5.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_6.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_7.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_8.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_9.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_10.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_11.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_12.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_13.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_14.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_15.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_16.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_17.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_18.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/energy/data/index_test_19.txt
# Number of training examples: 552
# Number of validation examples: 139
# Number of test examples: 77
# Number of train_original examples: 691
# ________________________________
#
#
# Dataset: kin8nm
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_0.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_1.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_2.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_3.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_4.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_5.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_6.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_7.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_8.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_9.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_10.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_11.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_12.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_13.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_14.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_15.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_16.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_17.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_18.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/kin8nm/data/index_test_19.txt
# Number of training examples: 5898
# Number of validation examples: 1475
# Number of test examples: 819
# Number of train_original examples: 7373
# ________________________________
#
#
# Dataset: naval-propulsion-plant
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_0.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_1.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_2.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_3.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_4.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_5.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_6.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_7.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_8.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_9.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_10.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_11.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_12.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_13.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_14.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_15.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_16.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_17.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_18.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/naval-propulsion-plant/data/index_test_19.txt
# Number of training examples: 8592
# Number of validation examples: 2149
# Number of test examples: 1193
# Number of train_original examples: 10741
# ________________________________
#
#
# Dataset: power-plant
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_0.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_1.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_2.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_3.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_4.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_5.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_6.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_7.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_8.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_9.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_10.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_11.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_12.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_13.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_14.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_15.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_16.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_17.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_18.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/power-plant/data/index_test_19.txt
# Number of training examples: 6888
# Number of validation examples: 1723
# Number of test examples: 957
# Number of train_original examples: 8611
# ________________________________
#
#
# Dataset: protein-tertiary-structure
# Number of splits: 5.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_test_0.txt
# Number of training examples: 32925
# Number of validation examples: 8232
# Number of test examples: 4573
# Number of train_original examples: 41157
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_test_1.txt
# Number of training examples: 32925
# Number of validation examples: 8232
# Number of test examples: 4573
# Number of train_original examples: 41157
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_test_2.txt
# Number of training examples: 32925
# Number of validation examples: 8232
# Number of test examples: 4573
# Number of train_original examples: 41157
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_test_3.txt
# Number of training examples: 32925
# Number of validation examples: 8232
# Number of test examples: 4573
# Number of train_original examples: 41157
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/protein-tertiary-structure/data/index_test_4.txt
# Number of training examples: 32925
# Number of validation examples: 8232
# Number of test examples: 4573
# Number of train_original examples: 41157
# ________________________________
#
#
# Dataset: wine-quality-red
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_0.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_1.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_2.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_3.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_4.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_5.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_6.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_7.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_8.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_9.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_10.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_11.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_12.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_13.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_14.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_15.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_16.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_17.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_18.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/wine-quality-red/data/index_test_19.txt
# Number of training examples: 1151
# Number of validation examples: 288
# Number of test examples: 160
# Number of train_original examples: 1439
# ________________________________
#
#
# Dataset: yacht
# Number of splits: 20.0
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_0.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_0.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_1.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_1.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_2.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_2.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_3.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_3.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_4.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_4.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_5.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_5.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_6.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_6.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_7.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_7.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_8.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_8.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_9.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_9.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_10.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_10.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_11.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_11.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_12.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_12.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_13.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_13.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_14.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_14.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_15.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_15.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_16.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_16.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_17.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_17.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_18.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_18.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_train_19.txt
# Loading file: ./DropoutUncertaintyExps/UCI_Datasets/yacht/data/index_test_19.txt
# Number of training examples: 221
# Number of validation examples: 56
# Number of test examples: 31
# Number of train_original examples: 277
